# %%
import pandas as pd

# %%
lines = 0
with open('corona-out-sample', 'r') as f:
    for line in f:
        lines += 1
        
print(lines)
# Out:
# 37036

# %%
# this code block allows you to inspect 2 tweets and 2 retweets in the dataset
# it also saves all the unique tweets/retweets in the dictionary tweets
# this code will help you to understand the data
# feel free to print out more fields

lines=0
num_tweets=0
num_retweets=0
print_tweet = 0
print_retweet = 0
tweets = {}
users = []

#insert path and replace name of the file below as needed
with open("corona-out-sample", "r") as f1:
    for line in f1:
        try:
            data = json.loads(line)
            lines = lines + 1

            if(data['user']['id_str'] == "16144221"):
                print("******************")
                print(data)
                print("****************")

        except:
            continue
            
print('num of lines=',lines, 'num of tweets=',num_tweets, 'num of retweets=',num_retweets)
print('num of unique tweets/retweets=',len(tweets.keys()))
print("no of users", len(users))
# Out:
# num of lines= 18518 num of tweets= 0 num of retweets= 0
# num of unique tweets/retweets= 0
# no of users 0

# %%
# this code block allows you to inspect 2 tweets and 2 retweets in the dataset
# it also saves all the unique tweets/retweets in the dictionary tweets
# this code will help you to understand the data
# feel free to print out more fields
import pandas as pd
lines=0
num_tweets=0
num_retweets=0
print_tweet = 0
print_retweet = 0
tweets = {}

#insert path and replace name of the file below as needed
with open("corona-out-sample", "r") as f1:
    for line in f1:
        try:
            data = json.loads(line)
            lines = lines + 1
            if ( data['text'].startswith('RT') ):
                num_retweets += 1
                if (print_retweet < 1):
                    print_retweet += 1

                    print("1*******")
                    df = pd.DataFrame([data['user']])
                    df.head()
                    df.info()
                    print(pd.io.sql.get_schema(df, name = 'twitter_users'))
                    print("2*****")

            
        except Exception as e:           
            continue
# Out:
# 1*******
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 39 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  1 non-null      int64
#  1   id_str                              1 non-null      object
#  2   name                                1 non-null      object
#  3   screen_name                         1 non-null      object
#  4   location                            1 non-null      object
#  5   url                                 1 non-null      object
#  6   description                         1 non-null      object
#  7   translator_type                     1 non-null      object
#  8   protected                           1 non-null      bool
#  9   verified                            1 non-null      bool
#  10  followers_count                     1 non-null      int64
# ...

# %%
import pandas as pd
import json
from sqlalchemy import create_engine

engine = create_engine('postgresql://postgres:root@localhost:5432/twitter')
engine.connect()

user_id = []
users = 0
with open("corona-out-sample", "r") as f1:
    for line in f1:
        try:
            data = json.loads(line)
            if data['user']['id'] not in user_id:
                users += 1
                df = pd.DataFrame([data['user']])
                df.to_sql(name= 'users', if_exists='append', con = engine, index = False)
                user_id.append(data['user']['id'])
                
            if data['retweeted_status']['user']['id'] not in user_id:
                users += 1
                df = pd.DataFrame([data['retweeted_status']['user']])
                df.to_sql(name= 'users', if_exists='append', con = engine, index = False)
                user_id.append(data['retweeted_status']['user']['id'])
            
        except Exception as e:
            continue
            
print("number of users:", users)
# Out:
# number of users: 18461

# %%
15505

# %% [markdown]
# # MongoDB

# %%
# !pip install pymongo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb://localhost:27017")

# %%
db = client["twitter"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'twitter')

# %%
import pandas as pd
import json

tweet_id = []
users = 0
with open("corona-out-sample", "r") as f1:
    for line in f1:
        try:
            data = json.loads(line)
            if data['id'] not in tweet_id: 
                db.tweets.insert_one(data)
                users += 1
                tweet_id.append(data['id'])
        
        except Exception as e:
            print(e)
            continue
            
print("number of users:", users)
# Out:
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# Expecting value: line 2 column 1 (char 1)
# ...

# %%
print(db.tweets.find())

# %%
db.tweets.drop()

# %%
db.tweets.countDocuments()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 db.tweets.countDocuments()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pymongo\collection.py:3213, in Collection.__call__(self, *args, **kwargs)
#    3206 if "." not in self.__name:
#    3207     raise TypeError(
#    3208         "'Collection' object is not callable. If you "
#    3209         "meant to call the '%s' method on a 'Database' "
#    3210         "object it is failing because no such method "
#    3211         "exists." % self.__name
#    3212     )
# -> 3213 raise TypeError(
#    3214     "'Collection' object is not callable. If you meant to "
#    3215     "call the '%s' method on a 'Collection' object it is "
#    3216     "failing because no such method exists." % self.__name.split(".")[-1]
#    3217 )
#
# ...

# %%
  "id" INTEGER,
  "name" TEXT,
  "screen_name" TEXT,
  "location" TEXT,
  "url" TEXT,
  "description" TEXT,
  "protected" INTEGER,
  "verified" INTEGER,
  "followers_count" INTEGER,
  "friends_count" INTEGER,
  "listed_count" INTEGER,
  "favourites_count" INTEGER,
  "statuses_count" INTEGER,
  "created_at" TEXT
